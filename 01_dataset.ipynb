# %%
from tabula import read_pdf
import numpy as np

# %%
fd = read_pdf("HI_assay/WIC-VCM-NH202425.pdf", pages="all")

# %%
#parse pdf .....
import fnmatch
def func(l, s):
    return [i for i in l if re.search(s, i)]
ll = []
cnt = 0
for i in range(len(fd)):
    ff = fd[i].columns.tolist()
    c = len(func(ff,'Haemagglutination'))
    if c == 1:
        ll.append(cnt)
    else:
        pass
    cnt +=1

# %%
#fd[3].iloc[:,3].str.split(' ', expand=True)

fd[ll[1]]
# Out:
#     Unnamed: 0                                         Unnamed: 1  Unnamed: 2  \
# 0          NaN                                                NaN         NaN
# 1          NaN                                      Viruses Other         NaN
# 2          NaN                                        information         NaN
# 3          NaN                                                NaN         NaN
# 4          NaN                                                NaN         NaN
# 5          NaN                            COPY AND PASTE VALUES!!         NaN
# 6          NaN                                  REFERENCE VIRUSES         NaN
# 7          NaN  IVR-215 (A/Victoria/2570/2019) K130N, N156K, L...         NaN
# 8          NaN  A/Sydney/5/2021 K54Q, A186T, E224A, R259K, K30...         NaN
# 9          NaN  A/Sydney/5/2021 K54Q, A186T, E224A, R259K, K30...         NaN
# 10         NaN  A/Victoria/4897/2022 P137S, K142R, T216A, D260...         NaN
# ...

# %%
ideal = fd[1].dropna(thresh=6).dropna(axis=1).iloc[:,[0,2,3,4,5,6,7]]
ideal.index = ideal.iloc[:,0]
df_ = ideal.iloc[:,1:]
df_
# Out:
#                                                       5a.2   5a.2a  5a.2a.1  \
# COPY AND PASTE VALUES!!
# IVR-215 (A/Victoria/2570/2019) K130N, N156K, L1...  1280.0   640.0    640.0
# A/Sydney/5/2021 K54Q, A186T, E224A, R259K, K308...  1280.0  1280.0   2560.0
# A/Sydney/5/2021 K54Q, A186T, E224A, R259K, K308...  1280.0   640.0   1280.0
# A/Victoria/4897/2022 P137S, K142R, T216A, D260E...  2560.0  1280.0   2560.0
# IVR-238 (A/Victoria/4897/2022) P137S, K142R, T2...   640.0   640.0    640.0
# A/Wisconsin/67/2022                                 1280.0   640.0   1280.0
# A/Catalonia/NSVH151105209/2023                      2560.0  2560.0   2560.0
# A/Catalonia/NSVH132634061/2023                      2560.0  2560.0   2560.0
# A/Catalonia/NSAV198281926/2023                      2560.0  1280.0   1280.0
# A/Catalonia/NSVH102162320/2023                      1280.0   640.0   1280.0
#
#                                                     5a.2a.1.1  5a.2a.1.2  \
# COPY AND PASTE VALUES!!
# ...

# %%
ncol_ = ideal.shape[1]
nrow_ = ideal.shape[0]
ll = []
index_ = []
for i in range(1,ncol_):
    
    x=np.log2(df_.iloc[:,i-1].to_frame())
    sample_ = x.index.tolist()
    cnt = 1
    for j in range(cnt,ncol_):
        
        x_2 = x.iloc[j-1:,]
        ref = x_2.iloc[0,0]
        candidate = x_2.iloc[1:,0]
        score = ref - candidate.to_numpy()
        ll.extend(score)
        index_sample.append([sample_[j-1],sample_[j]])

        xsample = x_2.index.tolist()
        xref = xsample[0]
        
        for k in range(len(xsample)-1):
            
            xy = xsample[k+1]+"___"+ xsample[0]
            index_.append(xy)

        cnt += 1

# %%
len(index_)
# Out:
# 234
